# %%
# %matplotlib inline

# %% [markdown]
# # Sankey of Napoleon's march on Moscow with custom colormap
#
# This example reproduces a famous historical flow map: Charles Joseph Minard's map depicting
# Napoleon's disastrously costly 1812 march on Russia during the Napoleonic Wars.
#
# This plot demonstrates building and using a custom ``matplotlib`` colormap. To learn more refer to
# `the matplotlib documentation
# <https://matplotlib.org/gallery/images_contours_and_fields/custom_cmap.html>`_.
#
# `Click here <https://bl.ocks.org/ResidentMario/ac2db57d1c6652ddbc4112a3d318c746>`_ to see an
# interactive scrolly-panny version of this webmap built with ``mplleaflet``. To learn more about
# ``mplleaflet``, refer to `the mplleaflet GitHub repo <https://github.com/jwass/mplleaflet>`_.

# %%
import geopandas as gpd
import geoplot as gplt
from matplotlib.colors import LinearSegmentedColormap

napoleon_troop_movements = gpd.read_file(gplt.datasets.get_path('napoleon_troop_movements'))

colors = [(215 / 255, 193 / 255, 126 / 255), (37 / 255, 37 / 255, 37 / 255)]
cm = LinearSegmentedColormap.from_list('minard', colors)

gplt.sankey(
    napoleon_troop_movements,
    scale='survivors', limits=(0.5, 45),
    hue='direction',
    cmap=cm
)

# Uncomment and run the following lines of code to save as an interactive webmap.
# import matplotlib.pyplot as plt
# import mplleaflet
# fig = plt.gcf()
# mplleaflet.save_html(fig, fileobj='minard-napoleon-russia.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 colors = [(215 / 255, 193 / 255, 126 / 255), (37 / 255, 37 / 255, 37 / 255)]
#       8 cm = LinearSegmentedColormap.from_list('minard', colors)
# ---> 10 gplt.sankey(
#      11     napoleon_troop_movements,
#      12     scale='survivors', limits=(0.5, 45),
#      13     hue='direction',
#      14     cmap=cm
#      15 )
#      17 # Uncomment and run the following lines of code to save as an interactive webmap.
#      18 # import matplotlib.pyplot as plt
#      19 # import mplleaflet
#      20 # fig = plt.gcf()
#      21 # mplleaflet.save_html(fig, fileobj='minard-napoleon-russia.html')
#
# File c:\Users\johnk\mambaforge\envs\env_tc\Lib\site-packages\geoplot\geoplot.py:1477, in sankey(df, projection, hue, norm, cmap, scheme, legend, legend_kwargs, legend_labels, legend_values, legend_var, extent, figsize, scale, scale_func, limits, ax, **kwargs)
#    1467         return ax
#    1469 plot = SankeyPlot(
#    1470     df, figsize=figsize, ax=ax, extent=extent, projection=projection,
#    1471     scale=scale, limits=limits, scale_func=scale_func,
#    (...)
#    1475     **kwargs
#    1476 )
# -> 1477 return plot.draw()
#
# File c:\Users\johnk\mambaforge\envs\env_tc\Lib\site-packages\geoplot\geoplot.py:1433, in sankey.<locals>.SankeyPlot.draw(self)
#    1428     else:
#    1429         raise ValueError(
#    1430             f'df.geometry must contain LineString, MultiLineString, or MultiPoint '
#    1431             f'geometries, but an instance of {type(geom)} was found instead.'
#    1432         )
# -> 1433 path_geoms = self.df.geometry.map(parse_geom)
#    1435 linestyle = kwargs.pop('linestyle', None)
#    1436 if linestyle is None:
#
# File c:\Users\johnk\mambaforge\envs\env_tc\Lib\site-packages\pandas\core\series.py:4397, in Series.map(self, arg, na_action)
#    4318 def map(
#    4319     self,
#    4320     arg: Callable | Mapping | Series,
#    4321     na_action: Literal["ignore"] | None = None,
#    4322 ) -> Series:
#    4323     """
#    4324     Map values of Series according to an input mapping or function.
#    4325
#    (...)
#    4395     dtype: object
#    4396     """
# -> 4397     new_values = self._map_values(arg, na_action=na_action)
#    4398     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4399         self, method="map"
#    4400     )
#
# File c:\Users\johnk\mambaforge\envs\env_tc\Lib\site-packages\pandas\core\base.py:924, in IndexOpsMixin._map_values(self, mapper, na_action)
#     921         raise ValueError(msg)
#     923 # mapper is a function
# --> 924 new_values = map_f(values, mapper)
#     926 return new_values
#
# File c:\Users\johnk\mambaforge\envs\env_tc\Lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# File c:\Users\johnk\mambaforge\envs\env_tc\Lib\site-packages\geoplot\geoplot.py:1427, in sankey.<locals>.SankeyPlot.draw.<locals>.parse_geom(geom)
#    1425     return geom
#    1426 elif isinstance(geom, shapely.geometry.MultiPoint):
# -> 1427     return shapely.geometry.LineString(geom)
#    1428 else:
#    1429     raise ValueError(
#    1430         f'df.geometry must contain LineString, MultiLineString, or MultiPoint '
#    1431         f'geometries, but an instance of {type(geom)} was found instead.'
#    1432     )
#
# File c:\Users\johnk\mambaforge\envs\env_tc\Lib\site-packages\shapely\geometry\linestring.py:66, in LineString.__new__(self, coordinates)
#      63             else:
#      64                 return [float(c) for c in o]
# ---> 66         coordinates = [_coords(o) for o in coordinates]
#      68 if len(coordinates) == 0:
#      69     # empty geometry
#      70     # TODO better constructor + should shapely.linestrings handle this?
#      71     return shapely.from_wkt("LINESTRING EMPTY")
#
# TypeError: 'MultiPoint' object is not iterable

# %%
napoleon_troop_movements.head()
# Out:
#   id  direction  survivors  group  \
# 0  1          0     340000      1
# 1  2          0     340000      1
# 2  3          0     320000      1
# 3  4          0     300000      1
# 4  5          0     280000      1
#
#                                             geometry
# 0  MULTIPOINT (24.50000 55.00000, 24.00000 54.90000)
# 1  MULTIPOINT (25.50000 54.50000, 24.50000 55.00000)
# 2  MULTIPOINT (26.00000 54.70000, 25.50000 54.50000)
# 3  MULTIPOINT (27.00000 54.80000, 26.00000 54.70000)
# 4  MULTIPOINT (28.00000 54.90000, 27.00000 54.80000)
